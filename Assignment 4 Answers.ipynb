# %% [markdown]
# # Question 1

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.1.2

# %% [markdown]
# # Question 2

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = np.array(['a', 'b', 'c', 'd', 'e'])
s = pd.Series(data, index =[1000, 1001, 1002, 1003, 1004]) 
print(s)
# Out:
# 1000    a
# 1001    b
# 1002    c
# 1003    d
# 1004    e
# dtype: object

# %% [markdown]
# # Question 3

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Roll Number': ['CSE09', 'CSE10', 'CSE11', 'CSE12'], 
                   'Name': ['Virat', 'Sam', 'Curran', 'Boult'], 
                   'Marks': [97, 90, 70, 82], 
                   'Grade': ['A', 'A', 'C', 'B'], 
                   'Subject': ['Physics', 'Physics', 'Physics', 'Physics']})
df
# Out:
#   Roll Number    Name  Marks Grade  Subject
# 0       CSE09   Virat     97     A  Physics
# 1       CSE10     Sam     90     A  Physics
# 2       CSE11  Curran     70     C  Physics
# 3       CSE12   Boult     82     B  Physics

# %%
new_df = df.reset_index(level=0, inplace=True)

# %%
df
# Out:
#    index Roll Number    Name  Marks Grade  Subject
# 0      0       CSE09   Virat     97     A  Physics
# 1      1       CSE10     Sam     90     A  Physics
# 2      2       CSE11  Curran     70     C  Physics
# 3      3       CSE12   Boult     82     B  Physics

# %% [markdown]
# # Question 4

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
mpg_dtset = sns.load_dataset('mpg')
mpg_dtset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# # Question 5

# %%
import seaborn as sns

# %%
mpg_dtset = sns.load_dataset('mpg')
print(mpg_dtset['origin'].unique())
# Out:
# ['usa' 'japan' 'europe']

# %% [markdown]
# # Question 6

# %%
import seaborn as sns

# %%
mpg_dtset = sns.load_dataset('mpg')
new_mpg_dtset = mpg_dtset[mpg_dtset['origin']=='usa']
new_mpg_dtset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin                       name
# 0            70    usa  chevrolet chevelle malibu
# ...
